# %% [markdown]
# <a href="https://colab.research.google.com/github/minhcong00/AI/blob/main/BT_AI_W7_50_Startups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = '/content/50_Startups.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Profit']),y=data['R&D Spend'])
print('Gia tri,Intercept la:',model.intercept_)
print('Gia tri coeffient la:',model.coef_)
model.score(pd.DataFrame(data['Profit']),data['R&D Spend'])

data.plot(kind='scatter',x='Profit',y='R&D Spend',figsize=(9,9),color='black')
y_pred=model.predict(X=pd.DataFrame(data['Profit']))
plt.plot(data['Profit'],y_pred,color='green')
# Out:
# Gia tri,Intercept la: -50385.82883510302
# Gia tri coeffient la: [1.10797715]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#hoi quy bac 2
import numpy as np
model=linear_model.LinearRegression()
X= pd.DataFrame([data['Profit'],data['Profit']**2]).T
model.fit(X,y=data['R&D Spend'])
print('He so Intercept la:',model.intercept_)
print('He so coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(pd.DataFrame([data['Profit'],data['Profit']**2]).T,data['R&D Spend']))

range = np.arange(data['Profit'].min(),data['Profit'].max(),0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Profit', y = 'R&D Spend', figsize = (9,9), color = 'blue', xlim = 0.7)
plt.plot(range, y_pred, color = 'red')
# Out:
# He so Intercept la: -37182.30912423563
# He so coeffient la: [8.39353178e-01 1.19427444e-06]
# Do chinh xac cua mo hinh: 0.9497292340096265
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#hoi quy bac 10
import numpy as np
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Profit'], data['Profit']**2, data['Profit']**3, data['Profit']**4, data['Profit']**5, data['Profit']**6, data['Profit']**7, data['Profit']**8, data['Profit']**9, data['Profit']**10]).T #Tranpose: chuyển vị
model.fit(X, y = data['R&D Spend'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['R&D Spend']))

range = np.arange(data['Profit'].min(),data['Profit'].max(),0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Profit', y = 'R&D Spend', figsize = (9,9), color = 'blue', xlim = 0.7)
plt.plot(range, y_pred, color = 'red')
# Out:
# Hệ số Intercept: 27822.35303197206
# Hệ số Coeffient: [ 5.77511864e-71  2.40859177e-39 -6.41671175e-46 -1.33638236e-51
#   1.84699387e-50  1.83008167e-45  1.50978126e-40  8.32524049e-36
#  -8.81680677e-41  2.35421651e-46]
# Độ chính xác của mô hình: 0.8868735762674258
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
