# %% [markdown]
# <a href="https://colab.research.google.com/github/minhcong00/AI/blob/main/BT_AI_W7_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = '/content/iris.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['petal.width']),y=data['sepal.length'])
print('Gia tri,Intercept la:',model.intercept_)
print('Gia tri coeffient la:',model.coef_)
model.score(pd.DataFrame(data['petal.width']),data['sepal.length'])

data.plot(kind='scatter',x='petal.width',y='sepal.length',figsize=(9,9),color='blue')
y_pred=model.predict(X=pd.DataFrame(data['petal.width']))
plt.plot(data['petal.width'],y_pred,color='red')
# Out:
# Gia tri,Intercept la: 4.7776294156015675
# Gia tri coeffient la: [0.88858025]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#hoi quy ham bac 2
import numpy as np
model=linear_model.LinearRegression()
X= pd.DataFrame([data['petal.width'],data['petal.width']**2]).T
model.fit(X,y=data['sepal.length'])
print('He so Intercept la:',model.intercept_)
print('He so coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(pd.DataFrame([data['petal.width'],data['petal.width']**2]).T,data['sepal.length']))

range = np.arange(data['petal.width'].min(),data['petal.width'].max(),0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'petal.width', y = 'sepal.length', figsize = (9,9), color = 'blue', xlim = 0.7)
plt.plot(range, y_pred, color = 'red')
# Out:
# He so Intercept la: 4.753487886607013
# He so coeffient la: [ 0.96150909 -0.03141821]
# Do chinh xac cua mo hinh: 0.6693431597032162
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#hoi quy ham bac 10
import numpy as np
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['petal.width'], data['petal.width']**2, data['petal.width']**3, data['petal.width']**4, data['petal.width']**5, data['petal.width']**6, data['petal.width']**7, data['petal.width']**8, data['petal.width']**9, data['petal.width']**10]).T
model.fit(X, y = data['sepal.length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['sepal.length']))

range = np.arange(data['petal.width'].min(),data['petal.width'].max(),0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'petal.width', y = 'sepal.length', figsize = (9,9), color = 'blue', xlim = 0.7)
plt.plot(range, y_pred, color = 'red')
# Out:
# Hệ số Intercept: 4.997722375291318
# Hệ số Coeffient: [  -5.20277857   52.25848682 -209.51148822  488.23422628 -730.42077024
#   712.72705391 -444.23113054  168.79681085  -35.42074849    3.13605012]
# Độ chính xác của mô hình: 0.7006294723079581
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#hoi quy ham bac 36
import numpy as np
from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['petal.width'], data['petal.width']**2, data['petal.width']**3, data['petal.width']**4, data['petal.width']**5,
                  data['petal.width']**6, data['petal.width']**7, data['petal.width']**8, data['petal.width']**9, data['petal.width']**10,
                  data['petal.width']**11, data['petal.width']**12, data['petal.width']**13, data['petal.width']**14, data['petal.width']**15,
                  data['petal.width']**16, data['petal.width']**17, data['petal.width']**18, data['petal.width']**19, data['petal.width']**20,
                  data['petal.width']**21, data['petal.width']**22, data['petal.width']**23, data['petal.width']**24, data['petal.width']**25,
                  data['petal.width']**26, data['petal.width']**27, data['petal.width']**28, data['petal.width']**29, data['petal.width']**30,
                  data['petal.width']**31, data['petal.width']**32, data['petal.width']**33, data['petal.width']**34, data['petal.width']**35,
                  data['petal.width']**36]).T
model.fit(X, y = data['sepal.length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['sepal.length']))

range = np.arange(data['petal.width'].min(),data['petal.width'].max(),0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,
                        range**11,range**12,range**13,range**14,range**15,range**16,range**17,range**18,range**19,range**20,
                        range**21,range**22,range**23,range**24,range**25,range**26,range**27,range**28,range**29,range**30,
                        range**31,range**32,range**33,range**34,range**35,range**36]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'petal.width', y = 'sepal.length', figsize = (9,9), color = 'blue', xlim = 0.7)
plt.plot(range, y_pred, color = 'red')
# Out:
# Hệ số Intercept: 4.671993344624838
# Hệ số Coeffient: [ 1.57045719e+00 -3.34755255e-01 -9.02253822e-01 -5.77168175e-01
#  -1.13081766e-01  2.52390820e-01  4.55008282e-01  4.93007691e-01
#   3.92659533e-01  1.98066636e-01 -3.40068018e-02 -2.41075257e-01
#  -3.65675383e-01 -3.69275016e-01 -2.46331996e-01 -3.32358261e-02
#   1.94454367e-01  3.41936526e-01  3.32448456e-01  1.52013478e-01
#  -1.20764048e-01 -3.29671187e-01 -3.20047110e-01 -6.18934747e-02
#   2.66153198e-01  3.54581089e-01  5.06386086e-02 -3.46234842e-01
#  -2.60053705e-01  3.04687261e-01  2.88331411e-01 -5.11077917e-01
#   2.99666904e-01 -9.02066996e-02  1.41246061e-02 -9.16956332e-04]
# Độ chính xác của mô hình: 0.705310644373897
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
